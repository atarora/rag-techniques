# %% [markdown]
# ### **Deep Researcher**
#
# Empower yourself with an intelligent agent capable of reasoning through extensive online resources and executing intricate, multi-stage research tasks.

# %%
# !uv pip install nest_asyncio tavily-python python-dotenv
# Out:
# Using Python 3.12.7 environment at: /home/xrd/Projects/atitaarora/rag-techniques/.venv
# Resolved 16 packages in 93ms
# Prepared 2 packages in 99ms
# Installed 16 packages in 7ms
#  + anyio==4.8.0
#  + certifi==2025.1.31
#  + charset-normalizer==3.4.1
#  + h11==0.14.0
#  + httpcore==1.0.7
#  + httpx==0.28.1
#  + idna==3.10
#  + nest-asyncio==1.6.0
#  + python-dotenv==1.0.1
#  + regex==2024.11.6
#  + requests==2.32.3
#  + sniffio==1.3.1
#  + tavily-python==0.5.1
#  + tiktoken==0.9.0
#  + typing-extensions==4.12.2
#  + urllib3==2.3.0

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# This notebook implements an AI researcher that persistently searches for information based on a user query until it's confident all necessary details have been gathered. It leverages several services:
#
# * [**Tavily:**](https://tavily.com/) To perform intelligent, AI-optimized searches and also to fetch and extract clean, LLM-friendly webpage content
# * [**OpenRouter:**](https://accounts.openrouter.ai/sign-in) To interact with a LLM for generating search queries, evaluating page relevance, and extracting context.
#
# ### Key Components
#
# #### Tavily Search Integration
#
# Tavily is dedicated to creating an advanced search layer that bridges large language models (LLMs) with the web, empowering AI agents with real-time, context-aware data. With its adaptable search functionalities, Tavily allows AI systems to refine search approaches, gather raw content for in-depth analysis, or obtain concise summaries for rapid understanding. Unlike traditional models limited by fixed training datasets, Tavily’s Search and Extract features integrate semantic, contextual, and keyword-based search methods to provide up-to-date, actionable insights, enhancing data-driven decision-making processes.
#
# #### Openrouter
#
# The system uses OpenRouter to interact with a language model for various tasks such as query generation, relevance assessment, and context extraction. This allows for dynamic and intelligent information gathering based on the evolving understanding of the user's query.

# %%
import asyncio
import aiohttp
import json
import logging
from tavily import AsyncTavilyClient
from typing import Dict, List, Optional
from dotenv import load_dotenv
import os

load_dotenv()  # take environment variables from .env.

# Initialize the Tavily client
tavily_client = AsyncTavilyClient(api_key=os.getenv("TAVILY_API_KEY")) if os.getenv("TAVILY_API_KEY") else TavilyClient()

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
DEFAULT_MODEL = os.getenv("DEFAULT_MODEL") 
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

async def call_openrouter_async(
    session: aiohttp.ClientSession,
    messages: List[Dict[str, str]],
    model: str = DEFAULT_MODEL,
    timeout: int = 15
) -> Optional[str]:
    """
    Asynchronously call the OpenRouter chat completion API with the provided messages and return the response.

    :param session: aiohttp ClientSession to use for the request.
    :param messages: List of messages to send to the API.
    :param model: Model to use for the completion.
    :param timeout: Timeout in seconds for the request.
    :return: The content of the assistant’s reply or None if an error occurs.
    """
    headers = {
        "Authorization": f"Bearer {OPENROUTER_API_KEY}",
        "X-Title": "OpenDeepResearcher",
        "Content-Type": "application/json"
    }
    payload = {
        "model": model,
        "messages": messages
    }

    try:
        async with session.post(os.getenv("OPENROUTER_URL"), headers=headers, json=payload, timeout=timeout) as resp:
            if resp.status == 200:
                result = await resp.json()
                try:
                    return result['choices'][0]['message']['content']
                except (KeyError, IndexError) as e:
                    logger.error("Unexpected OpenRouter response structure: %s", result)
                    return None
            else:
                text = await resp.text()
                logger.error("OpenRouter API error: %d - %s", resp.status, text)
                return None
    except aiohttp.ClientError as e:
        logger.error("Error calling OpenRouter: %s", e)
        return None
    except asyncio.TimeoutError:
        logger.error("OpenRouter API request timed out")
        return None

# %%
import ast

async def generate_search_queries_async(
    session: aiohttp.ClientSession,
    user_query: str,
    max_queries: int = 4
) -> List[str]:
    """
    Asynchronously generate up to four precise search queries based on the user's query using an LLM.

    Args:
        session (aiohttp.ClientSession): The aiohttp session to use for the API call.
        user_query (str): The user's query to generate search queries from.
        max_queries (int, optional): Maximum number of search queries to generate. Defaults to 4.

    Returns:
        List[str]: A list of search queries generated by the LLM. Returns an empty list if an error occurs.

    Example:
        >>> queries = await generate_search_queries_async(session, "What is the impact of AI on healthcare?")
        >>> print(queries)
        ['impact of AI on healthcare', 'AI applications in healthcare', 'benefits of AI in medicine', 'AI in healthcare research']
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        f"Return only a Python list of strings, for example: ['query1', 'query2', 'query3']. "
        f"Do not return more than {max_queries} queries."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]

    # Call the OpenRouter API
    response = await call_openrouter_async(session, messages)
    if not response:
        logger.error("No response received from the LLM.")
        return []

    try:
        # Safely evaluate the response to ensure it's a valid Python list
        search_queries = ast.literal_eval(response)
        if isinstance(search_queries, list):
            # Ensure the list contains only strings and trim to max_queries
            search_queries = [query.strip() for query in search_queries if isinstance(query, str)]
            return search_queries[:max_queries]
        else:
            logger.error("LLM did not return a valid list. Response: %s", response)
            return []
    except (ValueError, SyntaxError) as e:
        logger.error("Error parsing search queries: %s. Response: %s", e, response)
        return []

# %%
async def perform_search_async(session , query):
    """
    Perform an asynchronous search using the Tavily API.
    More info : https://docs.tavily.com/api-reference/endpoint/search

    Args:
        query (str): The search query.
        max_results (int, optional): Maximum number of results to return. Defaults to 5.
    """
    payload = {
    "query": query,
    "topic": "general",
    "search_depth": "basic",
    "max_results": 10, ## Modify it to go deeper
    "time_range": None,
    "days": 3, ##Remove this to get results from all the times
    "include_answer": True,
    "include_raw_content": True,
    "include_images": False,
    "include_image_descriptions": False,
    "include_domains": [],
    "exclude_domains": []
    }
    headers = {
        "Authorization": f"Bearer {os.getenv("TAVILY_API_KEY")}",
        "Content-Type": "application/json"
    }
    
    try:
        async with aiohttp.ClientSession() as session:
            async with session.post(os.getenv("TAVILY_SEARCH_URL"), json=payload, headers=headers) as resp:
                if resp.status == 200:
                    results = await resp.json()
                    return results
                else:
                    error_text = await resp.text()
                    logger.error(f"Tavily API error: {resp.status} - {error_text}")
                    return None
    except aiohttp.ClientError as e:
        logger.error(f"Error performing Tavily search: {e}")
        return None
    except Exception as e:
        logger.error(f"Unexpected error during Tavily search: {e}")
        return None

# %%
async def is_page_useful_async(session, user_query, page_text):
    """
    Determines whether the provided webpage content is useful for answering the given user query.
    
    The function queries an LLM with a strict prompt that requires a "Yes" or "No" response.
    If the model returns an unexpected response, the function attempts to extract "Yes" or "No" from it.
    
    Args:
        session: The HTTP session used for making asynchronous API requests.
        user_query (str): The user's search query.
        page_text (str): The text content of the webpage (truncated to 20,000 characters for processing).
    
    Returns:
        str: Either "Yes" or "No" indicating whether the page is useful for answering the query.
    """
    prompt = (
        "You are an expert evaluator of research relevance. Analyze the user's query and the provided webpage content. "
        "Determine whether the webpage contains valuable information that directly helps answer the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. "
        "Do not include any explanations, extra words, or formatting beyond 'Yes' or 'No'."
    )
    
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (truncated to 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    
    response = await call_openrouter_async(session, messages)
    
    if response:
        answer = response.strip()
        if answer in {"Yes", "No"}:
            return answer
        
        # Fallback: Attempt to extract "Yes" or "No" if extra text is included.
        if "Yes" in answer:
            return "Yes"
        elif "No" in answer:
            return "No"
    
    return "No"  # Default fallback to "No" if response is empty or ambiguous

# %%
async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Extracts relevant information from a webpage based on the user's query and the search query used.
    
    The function prompts an LLM to extract and return only the relevant context from the webpage content.
    No extra commentary or formatting is included in the response.
    
    Args:
        session: The HTTP session used for making asynchronous API requests.
        user_query (str): The original user query.
        search_query (str): The search query that led to the webpage.
        page_text (str): The text content of the webpage (truncated to 20,000 characters for processing).
    
    Returns:
        str: Extracted relevant information as plain text, or an empty string if no relevant context is found.
    """
    prompt = (
        "You are an expert information extractor. Analyze the user's query, the search query that led to this page, "
        "and the webpage content. Extract all pieces of information that are directly relevant to answering the user's query. "
        "Return only the extracted relevant context as plain text without any additional commentary or formatting."
    )
    
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (truncated to 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    
    response = await call_openrouter_async(session, messages)
    
    return response.strip() if response else ""

# %%
async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Determines whether additional search queries are needed based on the original query, past searches, and extracted contexts.
    
    If further research is needed, the function returns a Python list of up to four new search queries.
    If no further research is required, the function returns the string "<done>".
    
    Args:
        session: The HTTP session used for making asynchronous API requests.
        user_query (str): The original user query.
        previous_search_queries (list of str): A list of search queries previously used.
        all_contexts (list of str): A list of extracted relevant contexts from webpages.
    
    Returns:
        list[str] or str: A list of up to four new search queries if further research is needed, or "<done>" if no more searches are required.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>. "
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    
    response = await call_openrouter_async(session, messages)
    
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    
    return []

# %%
import asyncio
import random

async def generate_final_report_async(session, user_query, all_contexts, max_retries=5, initial_delay=1.0):
    """
    Generates a comprehensive final report using all gathered contexts relevant to the user's query.
    
    The function prompts an LLM to synthesize a well-structured and detailed report, incorporating key insights,
    citations, and conclusions from the collected contexts. It includes a retry mechanism with exponential backoff
    to handle API timeouts or failures.
    
    Args:
        session: The HTTP session used for making asynchronous API requests.
        user_query (str): The original user query.
        all_contexts (list of str): A list of extracted relevant contexts from various sources.
        max_retries (int): Maximum number of retry attempts.
        initial_delay (float): Initial delay between retries in seconds.
    
    Returns:
        str: A comprehensive report addressing the user's query, integrating all relevant insights and citations.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that thoroughly addresses the query. "
        "Incorporate all relevant insights, citation URLs, and conclusions without extraneous commentary. "
        "Ensure clarity, coherence, and factual accuracy."
    )
    
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    
    retries = 0
    delay = initial_delay
    
    while retries < max_retries:
        try:
            report = await call_openrouter_async(session, messages)
            if report:
                return report.strip()
            else:
                print(f"Attempt {retries + 1} failed: No report generated.")
        except Exception as e:
            print(f"Attempt {retries + 1} failed with error: {e}")
        
        # Exponential backoff with jitter
        delay *= 2
        jitter = random.uniform(0.5, 1.5)
        await asyncio.sleep(delay * jitter)
        retries += 1
    
    print("Max retries reached. Unable to generate the final report.")
    return ""

# %%
async def process_link(session, link, user_query, link_data):
    """
    Processes a single link by evaluating its usefulness and extracting relevant context if applicable.
    
    This function uses the pre-fetched content from the `unique_links` dictionary to determine
    the relevance of the page to the user's query and extracts meaningful information if the page
    is deemed useful.
    
    Args:
        session: The HTTP session used for making asynchronous API requests.
        link (str): The URL of the webpage to process.
        user_query (str): The original user query.
        link_data (dict): A dictionary containing the following keys:
            - "query": The search query that led to the webpage.
            - "content": The extracted content from the webpage.
            - "raw_content": The raw content from the webpage.
    
    Returns:
        str or None: Extracted relevant context if the page is useful, otherwise None.
    """
    print(f"Processing link: {link}")
    
    # Extract content from link_data
    page_text = link_data.get("content")  # Use "content" or "raw_content" as needed
    search_query = link_data.get("query")
    
    if not page_text:
        print(f"No content available for {link}")
        return None
    
    # Evaluate the usefulness of the page
    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")
    
    # If the page is useful, extract relevant context
    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context
    
    return None

# %%
async def async_main():
    """
    Perform an iterative deep research process using LLM-generated search queries and web scraping.

    This method:
    1. Takes a user query and an optional iteration limit as input.
    2. Generates initial search queries using an LLM.
    3. Performs web searches for each query and aggregates unique links.
    4. Fetches, judges, and extracts useful content from each link.
    5. Iteratively asks the LLM if more searches are needed and generates new queries.
    6. Compiles a final report based on the aggregated research data.

    Example:
        >>> asyncio.run(async_main())
        Enter your deep research query/topic: What is the impact of AI on healthcare?
        Enter maximum number of iterations (default 10): 5
        === Iteration 1 ===
        Aggregated 15 unique links from this iteration.
        LLM provided new search queries: ['AI in healthcare research', 'benefits of AI in medicine']
        === Iteration 2 ===
        Aggregated 10 unique links from this iteration.
        LLM indicated that no further research is needed.
        Generating final report...
        ==== FINAL REPORT ====
        "The impact of AI on healthcare is significant..."
    """
    # Get user input
    user_query = input("Enter your deep research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    # Initialize research data
    aggregated_contexts: List[str] = []  # All useful contexts from every iteration
    all_search_queries: List[str] = []   # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:

        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts: List[str] = []

            # For each search query, perform Tavily searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)
            
            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to its associated data (query, content, raw_content).
            unique_links = {}
            for idx, result in enumerate(search_results):
                query = new_search_queries[idx]
                if result and "results" in result:  # Ensure the result is valid and contains "results"
                    for item in result["results"]:
                        link = item.get("url")
                        if link and link not in unique_links:  # Ensure the link is valid and not already processed
                            unique_links[link] = {
                                "query": query,  # The search query that produced this link
                                "content": item.get("content"),  # Extracted content
                                "raw_content": item.get("raw_content")  # Raw content
                            }
            
            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)
            
            # Collect non-None contexts
            iteration_contexts = [res for res in link_results if res]
            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")
            

            new_search_queries = await get_new_search_queries_async(
                session, user_query, all_search_queries, aggregated_contexts
            )
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        print("\nPreparing final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== DEEP RESEARCH REPORT ====\n")
        print(final_report)

# %% [markdown]
# #### **Why Deep Research Outperforms LLM Prompting**
#
# - **Real-Time & Reliable** – Access to current, verifiable data; no hallucinations.
# - **Precision & Accuracy** – Technical specs, numbers, and documentation that LLMs may distort.
# - **Specialized Expertise** – Industry regulations, niche knowledge, and historical insights.
# - **Evidence-Backed Insights** – Case studies, market trends, and real-world validation.
#
# **Bottom Line: LLMs assist, but deep research ensures truth, accuracy, and trust—critical for high-stakes decisions.**
#
# **Let's Put our deep research to test using the question below :**
#
# We can conduct a deep research on any topic of our choice such as below.
#
# **Enter your deep research query/topic:**  What are the key differences in design philosophies between the Boeing 787 and Airbus A350, and how do they impact fuel efficiency?
#
# **Enter maximum number of iterations (default 10):**  3

# %%
def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your deep research query/topic:  What are the key differences in design philosophies between the Boeing 787 and Airbus A350, and how do they impact fuel efficiency?
# Enter maximum number of iterations (default 10):  3
# === Iteration 1 ===
# Aggregated 35 unique links from this iteration.
# Processing link: https://myaircraftcost.com/boeing-787-vs-airbus-a350-a-comprehensive-comparison/
# Processing link: https://aerospaceer.com/boeing-b787-vs-airbus-a350/
# Processing link: https://myaircraftcost.com/boeing-787-dreamliner-vs-airbus-a350-a-comprehensive-comparison/
# Processing link: https://myeasyflight.substack.com/p/plane-comparison-airbus-a350-vs-boeing
# Processing link: https://www.aviationfile.com/boeing-787-dreamliner-vs-airbus-a350-xwb-a-comprehensive-comparison-of-next-generation-wide-body-aircraft/
# Processing link: https://simpleflying.com/787-a350-composite/
# Processing link: https://myaircraftcost.com/boeing-787-9-vs-a350-900-a-comprehensive-comparison/
# Processing link: https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a350-a-mechanics-view/
# Processing link: https://theflyingengineer.com/boeing-787-vs-airbus-a350-battle-of-the-skies/
# Processing link: https://thisvsthat.io/a350-vs-b787
# Processing link: https://www.coursesidekick.com/industrial-engineering/907651
# Processing link: https://myaircraftcost.com/boeing-dreamliner-vs-airbus-a350-a-comprehensive-comparison/
# Processing link: https://myaircraftcost.com/boeing-787-9-vs-a350-900-a-comprehensive-comparison-2/
# Processing link: https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a350-900-a-comparison/
# Processing link: https://theluxurytravelexpert.com/a350-vs-b787-dreamliner-best-plane/
# Processing link: https://www.longdom.org/open-access/wings-of-innovation-and-unraveling-the-secrets-of-aircraft-design-107578.html
# Processing link: https://aeroplanetech.com/airbus-a350-innovations/
# Processing link: https://awbi.org/modern-aircraft-essentials/
# Processing link: https://www.afrlhorizons.com/the-future-of-aeroelastic-technology-in-aviation/
# Processing link: https://mycarmakesnoise.com/general/unbelievable-feats-of-engineering-in-modern-aircraft-design/
# Processing link: https://aeroplanetech.com/high-speed-performance-factors/
# Processing link: https://aeroplanetech.com/twin-aisle-aircraft/
# Processing link: https://simpleflying.com/boeing-787-dreamliner-impressive-wing-flex/
# Page usefulness for https://myaircraftcost.com/boeing-787-9-vs-a350-900-a-comprehensive-comparison/: Yes
# Page usefulness for https://ijcrt.org/papers/IJCRT2406889.pdf: No
# Page usefulness for https://aerospaceer.com/boeing-b787-vs-airbus-a350/: Yes
# Page usefulness for https://simpleflying.com/boeing-787-dreamliner-impressive-wing-flex/: No
# Page usefulness for https://www.executivetraveller.com/news/airbus-lightweight-composite-a320-future-wing-aims-to-best-boeing: No
# Page usefulness for https://awbi.org/modern-aircraft-essentials/: No
# Page usefulness for https://aviationguy.com/2013/12/05/airbus-and-mit-teaming-up-to-make-aircraft-construction-lighter-and-cheaper/: No
# Page usefulness for https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a350-a-mechanics-view/: Yes
# Page usefulness for https://aeroplanetech.com/twin-aisle-aircraft/: No
# Page usefulness for https://www.sciencedirect.com/science/article/pii/1044580395000666: No
# Page usefulness for https://theluxurytravelexpert.com/a350-vs-b787-dreamliner-best-plane/: No
# Page usefulness for https://aeroplanetech.com/airbus-a350-innovations/: Yes
# Page usefulness for https://myaircraftcost.com/boeing-dreamliner-vs-airbus-a350-a-comprehensive-comparison/: Yes
# Page usefulness for https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a350-900-a-comparison/: Yes
# Extracted context from https://myaircraftcost.com/boeing-dreamliner-vs-airbus-a350-a-comprehensive-comparison/ (first 200 chars): Design Philosophy and Fuel Efficiency:
# - Boeing 787 Dreamliner achieves 20% better fuel efficiency compared to older aircraft
# - Fuel efficiency is attributed to lightweight design and advanced engines
# Extracted context from https://myaircraftcost.com/boeing-787-dreamliner-vs-airbus-a350-a-comprehensive-comparison/ (first 200 chars): Boeing 787 is made up of approximately 50% composite materials, which significantly contributes to its lightweight structure and improves fuel efficiency. Boeing's official materials indicate this des
# Extracted context from https://myaircraftcost.com/boeing-787-9-vs-a350-900-a-comprehensive-comparison/ (first 200 chars): The webpage content provides limited information about the Boeing 787 and Airbus A350's design philosophies. The excerpt indicates that the Airbus A350-900 uses a mixed-material structure combining al
# Extracted context from https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a350-a-mechanics-view/ (first 200 chars): The webpage excerpt provides limited context about the A350's design, mentioning a hybrid structure combining aluminum alloys and composite materials. However, the provided content is incomplete and d
# Extracted context from https://myaircraftcost.com/boeing-787-vs-airbus-a350-a-comprehensive-comparison/ (first 200 chars): Based on the truncated webpage content, the key insight is about the Boeing 787's design philosophy of using composite materials:
#
# The Boeing 787 is constructed with approximately 50% composite materi
# Extracted context from https://myeasyflight.substack.com/p/plane-comparison-airbus-a350-vs-boeing (first 200 chars): The Boeing 787 features a raked wingtip design while the Airbus A350 features an embedded winglet. The Boeing 787 is made of 50% composite material. The different wing designs suggest variations in ae
# Extracted context from https://aerospaceer.com/boeing-b787-vs-airbus-a350/ (first 200 chars): Key design differences in composite materials:
# - Boeing 787: 50% composite materials
# - Airbus A350: 53% composite materials
#
# Boeing 787 wing design:
# - Wings designed to flex during flight
# - Reduces tu
# Extracted context from https://theflyingengineer.com/boeing-787-vs-airbus-a350-battle-of-the-skies/ (first 200 chars): Composite materials are a key design philosophy for the Boeing 787, which uses composites for approximately half of its structure, including the fuselage and wings. This approach is aimed at reducing
# Extracted context from https://www.sciencedirect.com/topics/engineering/boeing-787-dreamliner (first 200 chars): The Airbus A350 XWB uses advanced lightweight materials including:
# - Composites in fuselage, wings, and tail sections
# - Aluminum-lithium alloys in floor beams and structural frames
#
# The excerpt provid
# Extracted context from https://www2.gvsu.edu/peirsonb/term_paper.pdf (first 200 chars): The provided webpage excerpt provides limited information directly addressing the user's query about design philosophies and fuel efficiency differences between the Boeing 787 and Airbus A350. The onl
# Extracted context from https://www.aviationfile.com/boeing-787-dreamliner-vs-airbus-a350-xwb-a-comprehensive-comparison-of-next-generation-wide-body-aircraft/ (first 200 chars): The Boeing 787 Dreamliner uses a groundbreaking design with its fuselage composed of 50% carbon-fiber-reinforced plastic (CFRP), which significantly reduces aircraft weight. This material choice enabl
# Extracted context from https://aeroplanetech.com/airbus-a350-innovations/ (first 200 chars): The Airbus A350 features an enhanced aerodynamic profile designed to minimize drag and optimize fuel consumption. The design demonstrates a focus on engineering innovations that improve overall aircra
# Extracted context from https://simpleflying.com/787-a350-composite/ (first 200 chars): Boeing 787:
# - 50% composites by weight
# - 80% composites by volume
# - Additional material composition:
#   - 20% aluminum
#   - 15% titanium
#   - 10% steel
#   - 5% other materials
#
# Key design philosophy focus
# Extracted context from https://www.coursesidekick.com/industrial-engineering/907651 (first 200 chars): Design Philosophy and Fuel Efficiency Comparison:
#
# Both the Boeing 787 and Airbus A350 are technologically advanced commercial aircraft focused on:
# - Passenger comfort
# - Maximizing fuel efficiency
# - M
# Extracted context from https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a350-900-a-comparison/ (first 200 chars): Design Philosophy and Fuel Efficiency Differences:
#
# Boeing 787:
# - Notable for its fuel efficiency
# - Lower maintenance costs
#
# Airbus A350:
# - Higher passenger capacity
# - Longer range capability
#
# Both ai
# LLM provided new search queries: ['Detailed comparison of Boeing 787 and Airbus A350 wing design aerodynamics', 'Specific fuel efficiency metrics for Boeing 787 and Airbus A350', 'Quantitative analysis of composite material impact on aircraft performance', 'Manufacturing techniques for composite aircraft structures Boeing and Airbus']
#
# === Iteration 2 ===
# Aggregated 35 unique links from this iteration.
# Processing link: https://www.airliners.net/forum/viewtopic.php?t=1458471
# Processing link: https://aerofleets.com/boeing-787-vs-airbus-a350-a-comparison/
# Processing link: https://myaircraftcost.com/boeing-787-vs-airbus-a350-a-comprehensive-comparison/
# Processing link: https://myaircraftcost.com/boeing-787-8-vs-airbus-a350-900-a-comprehensive-comparison/
# Processing link: https://www.webflite.com/compare/airliners/787-9/a350-900
# Processing link: https://www.webflite.com/compare/airliners/787-8/a350-900
# Processing link: https://theflyingengineer.com/boeing-787-vs-airbus-a350-battle-of-the-skies/
# Processing link: https://myaircraftcost.com/boeing-787-dreamliner-vs-airbus-a350-a-comprehensive-comparison/
# Processing link: https://www.aviationfile.com/boeing-787-dreamliner-vs-airbus-a350-xwb-a-comprehensive-comparison-of-next-generation-wide-body-aircraft/
# Extracted context from https://myaircraftcost.com/boeing-787-dreamliner-vs-airbus-a350-a-comprehensive-comparison/ (first 200 chars): Boeing 787 Dreamliner is designed to be 20% more fuel-efficient compared to older aircraft. The A350 generally has lower maintenance costs. Both aircraft are advanced models designed for efficiency an
# Extracted context from https://www.ati.org.uk/wp-content/uploads/2021/08/insight_9-composites_amended-2018-09-20.pdf (first 200 chars): Based on the truncated webpage content provided, there is insufficient information to comprehensively answer the user's query about the design philosophies and fuel efficiency differences between the
# Extracted context from https://www.aircraft-commerce.com/wp-content/uploads/aircraft-commerce-docs/Analysis+&+Fleet+Planning/2016/108_ANALYSIS.pdf (first 200 chars): Based on the truncated content, there is limited specific information directly addressing the full query. The only relevant extracted details are:
#
# - The Boeing 787-8 entered service in 2011
# - The Boe
# Extracted context from https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a350-900-a-comparison/ (first 200 chars): Fuel efficiency comparison between Boeing 787 and Airbus A350:
# - Boeing 787-9 is notable for its superior fuel efficiency and lower maintenance costs
# - Airbus A350-900 offers higher passenger capacity
# Extracted context from https://aerofleets.com/boeing-787-vs-airbus-a350-a-comparison/ (first 200 chars): The Boeing 787 and Airbus A350 share similar specifications across their variant models. The primary design differences are focused on the fuselage and wing architectures. While the webpage content do
# Extracted context from https://myaircraftcost.com/boeing-787-vs-airbus-a350-a-comprehensive-comparison/ (first 200 chars): The Boeing 787 is lighter and more fuel-efficient, with lower operating costs due to advanced materials and design. The A350's aerodynamic design also enhances fuel efficiency, particularly for long-h
# Extracted context from https://www.semanticscholar.org/paper/IMPACT-OF-COMPOSITE-MATERIALS-ON-AIRCRAFT-WEIGHT-IN-Rafi/1d16a9a07df543c85de4269726b03a1dac1587d9 (first 200 chars): The content provided appears to be a truncated excerpt from a technical document and does not contain sufficient detailed information to fully address the specific differences between the Boeing 787 a
# LLM provided new search queries: ['Boeing 787 and Airbus A350 wing aerodynamics performance analysis', 'Detailed composite material weight reduction impact on aircraft fuel efficiency', 'Comparative engineering design philosophy Boeing 787 vs Airbus A350 technical white papers', 'Precise fuel efficiency metrics and operational cost differences between Boeing 787 and A350']
#
# === Iteration 3 ===
# Aggregated 29 unique links from this iteration.
# Processing link: https://www.coursehero.com/file/209840758/Aircraft-Design-and-Performance-Module-23docx/
# Processing link: https://myaircraftcost.com/boeing-787-8-vs-airbus-a350-900-a-comprehensive-comparison/
# Processing link: https://myaircraftcost.com/boeing-787-vs-airbus-a350-a-comprehensive-comparison/
# Processing link: https://myaircraftcost.com/boeing-787-dreamliner-vs-airbus-a350-a-comprehensive-comparison/
# Processing link: https://thisvsthat.io/a350-vs-b787
# Processing link: https://myaircraftcost.com/boeing-787-9-vs-a350-900-a-comprehensive-comparison-2/
# Processing link: https://simpleflying.com/boeing-787-vs-the-airbus-a350/
# Processing link: https://aerospaceer.com/boeing-b787-vs-airbus-a350/
# Processing link: https://www.webflite.com/compare/airliners/787-9/a350-900
# Processing link: https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a350-900-a-comparison/
# Processing link: https://www.semanticscholar.org/paper/IMPACT-OF-COMPOSITE-MATERIALS-ON-AIRCRAFT-WEIGHT-IN-Rafi/1d16a9a07df543c85de4269726b03a1dac1587d9
# Page usefulness for https://www.coursehero.com/file/209840758/Aircraft-Design-and-Performance-Module-23docx/: Yes
# Page usefulness for https://www.aviationfile.com/boeing-787-dreamliner-vs-airbus-a350-xwb-a-comprehensive-comparison-of-next-generation-wide-body-aircraft/: Yes
# Page usefulness for https://aerospaceer.com/boeing-b787-vs-airbus-a350/: Yes
# Page usefulness for https://www.mhi.co.jp/technology/review/pdf/e594/e594170.pdf: No
# Page usefulness for https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a380-a-detailed-comparison/: Yes
# Page usefulness for https://theflyingengineer.com/boeing-787-vs-airbus-a350-battle-of-the-skies/: No
# Page usefulness for https://myaircraftcost.com/boeing-787-9-vs-a350-900-a-comprehensive-comparison/: No
# Page usefulness for https://www.cdiproducts.com/blog/revolutionizing-aerospace-the-impact-of-composites-in-aviation: No
# Page usefulness for https://myaircraftcost.com/boeing-787-vs-airbus-a350-a-comprehensive-comparison/: Yes
# Page usefulness for https://www.aircraft-commerce.com/wp-content/uploads/aircraft-commerce-docs/Analysis+&+Fleet+Planning/2016/108_ANALYSIS.pdf: Yes
# Page usefulness for https://aerospaceer.com/composite-materials-in-aircraft/: Yes
# Page usefulness for https://airinsight.com/comparing-the-airbus-a350-900-and-boeing-787-9/: No
# Page usefulness for https://www.sensxpert.com/blog/impact-composites-aviation-industry/: Yes
# Page usefulness for https://www.wecanfigurethisout.org/ENERGY/Web_notes/Energy_Consumption/Transportation_Supporting_Files/Composites+in+the+Aircraft+Industry+-+Appropedia.pdf: Yes
# Page usefulness for https://pia.edu/blogs/composites-in-the-aircraft-industry/: No
# Page usefulness for https://www.researchgate.net/publication/387497678_COMPOSITE_MATERIALS_USED_IN_ARJ21_AIRCRAFT: No
# Page usefulness for https://myaircraftcost.com/boeing-787-9-vs-boeing-787-10-a-comprehensive-comparison/: Yes
# Page usefulness for https://simpleflying.com/boeing-787-vs-the-airbus-a350/: No
# Extracted context from https://aeropeep.com/what-aircraft-is-better-the-airbus-a350-900-or-the-boeing-787-9/ (first 200 chars): The A350 has a more advanced composite airframe, with 53% of the structure made from composites compared to 50% on the 787. This contributes to the A350's slightly lower operating empty weight and bet
# Extracted context from https://www.coursehero.com/file/209840758/Aircraft-Design-and-Performance-Module-23docx/ (first 200 chars): The Boeing 787-9 incorporates lightweight composite materials, a streamlined wing design, and advanced aerodynamics, resulting in reduced drag and enhanced fuel efficiency. The text provides limited d
# Extracted context from https://www.semanticscholar.org/paper/IMPACT-OF-COMPOSITE-MATERIALS-ON-AIRCRAFT-WEIGHT-IN-Rafi/1d16a9a07df543c85de4269726b03a1dac1587d9 (first 200 chars): Unfortunately, the provided webpage content appears to be truncated and does not contain sufficient information to comprehensively answer the user's specific query about the design differences between
# Extracted context from https://www.aircraft-commerce.com/wp-content/uploads/aircraft-commerce-docs/Analysis+&+Fleet+Planning/2016/108_ANALYSIS.pdf (first 200 chars): The 787 was originally pitched to offer fuel burns up to 20% lower than similar-sized previous generation aircraft. The 787-8 is about 3,500 to 5,500 nautical miles in range, slightly larger than the
# Extracted context from https://thisvsthat.io/a350-vs-b787 (first 200 chars): Aerodynamics and fuel efficiency are key differences between the Airbus A350 and Boeing 787. The A350 features advanced aerodynamics and efficient engines that contribute to its fuel efficiency. The B
# Extracted context from https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a380-a-detailed-comparison/ (first 200 chars): The Boeing 787-9 Dreamliner is designed with composite materials that reduce aircraft weight and improve fuel efficiency. While the provided content is limited, it offers a partial insight into Boeing
# Extracted context from https://www.webflite.com/compare/airliners/787-9/a350-900 (first 200 chars): Fuel capacity of Boeing 787-9: Not specified in this excerpt
# Fuel capacity of Airbus A350-900: 37,248 US gallons (141,000 liters)
# Range of Airbus A350-900: 8,300 nautical miles (15,372 kilometers)
#
# Th
# Extracted context from https://myaircraftcost.com/boeing-787-dreamliner-vs-airbus-a350-a-comprehensive-comparison/ (first 200 chars): Design Philosophy Differences:
# - Both Boeing 787 and Airbus A350 are advanced aircraft focused on efficiency and passenger comfort
# - Boeing 787 Dreamliner is designed to be 20% more fuel-efficient com
# Extracted context from https://myaircraftcost.com/boeing-787-vs-airbus-a350-a-comprehensive-comparison/ (first 200 chars): The Boeing 787 is lighter and more fuel-efficient, with lower operating costs due to advanced materials and design. The A350's aerodynamic design also enhances fuel efficiency, particularly for long-h
# Extracted context from https://myaircraftcost.com/boeing-787-9-vs-boeing-787-10-a-comprehensive-comparison/ (first 200 chars): Boeing 787-9: 2.6 liters/100 km fuel burn per seat
# Boeing 787-10: 2.8 liters/100 km fuel burn per seat
#
# The provided content offers limited details on design philosophies or comprehensive comparative
# Extracted context from https://myaircraftcost.com/boeing-787-9-dreamliner-vs-airbus-a350-900-a-comparison/ (first 200 chars): Airbus A350-900 features:
# - Higher purchase price but lower operational costs
# - Fuel efficiency improvement of approximately 25% compared to older aircraft
# - Spacious cabin with larger windows
# - Optim
# Extracted context from https://myaircraftcost.com/boeing-787-8-vs-airbus-a350-900-a-comprehensive-comparison/ (first 200 chars): Key wing design differences:
# - Boeing 787-8 has a distinctive raked wingtip design aimed at improving aerodynamic performance
# - Airbus A350-900 features a more traditional wing shape
# - Both aircraft a
# Extracted context from https://aerospaceer.com/boeing-b787-vs-airbus-a350/ (first 200 chars): Composite materials composition: Boeing 787 is made of 50% composite materials, which contributes to its lighter weight and improved fuel efficiency
#
# Fuel efficiency comparison: The A350 has slightly
# Extracted context from https://www.sensxpert.com/blog/impact-composites-aviation-industry/ (first 200 chars): In this truncated search result, the content provides limited context related to aircraft design and fuel efficiency. While the snippet mentions that composite materials like plastics contribute to we
# Extracted context from https://aerospaceer.com/composite-materials-in-aircraft/ (first 200 chars): Based on the webpage content provided, there is limited specific information directly addressing the detailed design philosophies of the Boeing 787 and Airbus A350. The only relevant extract is the ge
# Extracted context from https://www.wecanfigurethisout.org/ENERGY/Web_notes/Energy_Consumption/Transportation_Supporting_Files/Composites+in+the+Aircraft+Industry+-+Appropedia.pdf (first 200 chars): The provided webpage content offers limited information directly addressing the user's query. The key relevant extract is:
#
# Composite materials in aircraft design can reduce component weight by approx
# Extracted context from https://www.aviationfile.com/boeing-787-dreamliner-vs-airbus-a350-xwb-a-comprehensive-comparison-of-next-generation-wide-body-aircraft/ (first 200 chars): Based on the available content, here are the key extracted details relevant to the design philosophies and fuel efficiency differences:
#
# Both the Boeing 787 and Airbus A350 represent next-generation w
# LLM provided new search queries: ['Detailed engineering comparison Boeing 787 and Airbus A350 composite wing design aerodynamics', 'Quantitative fuel efficiency metrics Boeing 787 Dreamliner versus Airbus A350 XWB performance', 'Official technical specifications Boeing 787 and Airbus A350 composite material weight reduction strategies', 'Comparative analysis of Boeing 787 and Airbus A350 advanced materials engineering design philosophy']
#
# Preparing final report...
#
# ==== DEEP RESEARCH REPORT ====
#
# Comparative Analysis: Design Philosophies and Fuel Efficiency of Boeing 787 and Airbus A350
#
# Executive Summary:
# This report examines the key design philosophies and fuel efficiency characteristics of the Boeing 787 Dreamliner and Airbus A350 XWB, two next-generation wide-body commercial aircraft that represent significant advancements in aerospace engineering.
#
# 1. Composite Materials Design Philosophy
#
# Material Composition:
# - Boeing 787: 50% composites by weight (80% by volume)
#   - Material breakdown:
#     * 20% aluminum
#     * 15% titanium
#     * 10% steel
#     * 5% other materials
#
# - Airbus A350: 53% composites by weight
#   - Utilizes advanced aluminum-lithium alloys
#   - Composite materials in fuselage, wings, and tail sections
#
# 2. Fuel Efficiency Characteristics
#
# Performance Metrics:
# - Boeing 787:
#   * 20% improved fuel efficiency compared to previous generation aircraft
#   * Fuel burn: 2.6-2.8 liters/100 km per seat
#   * Range: 3,500-5,500 nautical miles (787-8 variant)
#
# - Airbus A350:
#   * Approximately 25% fuel efficiency improvement
#   * Range: Up to 8,300 nautical miles
#   * Powered by Rolls-Royce Trent XWB engines
#
# 3. Distinctive Design Approaches
#
# Boeing 787 Key Design Features:
# - Flexible wing design to reduce turbulence
# - Innovative single-barrel fuselage construction
# - Raked wingtip design
# - Focus on passenger comfort and lower maintenance costs
#
# Airbus A350 Key Design Features:
# - Curved, high-aspect-ratio wings
# - Embedded winglets
# - Wider fuselage for enhanced passenger space
# - Advanced aerodynamic profile to minimize drag
#
# 4. Comparative Analysis
#
# Strengths:
# Boeing 787:
# - Lower maintenance costs
# - More flexible for different route configurations
# - Innovative lightweight design
#
# Airbus A350:
# - Longer range capabilities
# - Slightly higher passenger capacity
# - More advanced wing composite construction
#
# 5. Technological Innovation Similarities
#
# Common Design Priorities:
# - Extensive use of composite materials
# - Focus on fuel efficiency
# - Enhanced passenger comfort
# - Reduced environmental impact
# - Advanced aerodynamic engineering
#
# Conclusion:
# Both the Boeing 787 and Airbus A350 represent breakthrough designs in commercial aviation, with marginally different approaches to achieving fuel efficiency and operational performance. The primary distinction lies in their specific design implementations rather than fundamental design philosophies.
#
# Recommendations:
# - Airlines should evaluate aircraft selection based on specific route requirements
# - Consider long-term operational costs beyond initial fuel efficiency metrics
# - Recognize that both aircraft offer significant technological advancements over previous generations
#
# Limitations of Analysis:
# This report is based on available published data and may not reflect the most recent technological updates or specific airline configurations.
#
# Prepared by: AI Research Assistant
# Date: [Current Date]
#
# Note: While comprehensive, this analysis synthesizes available information and should be complemented with manufacturer-specific technical documentation for absolute precision.
